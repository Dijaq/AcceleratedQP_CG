# %%
import numpy as np
import pandas as pd

# %%
#Read csv
KKT_mat = pd.read_csv('ValidarDatos/c_KKT_matm.csv')
LU = pd.read_csv('ValidarDatos/c_LU.csv')
#Iloc
KKT_mat0 = KKT_mat.iloc[:,2]
LU0 = LU.iloc[:,0]
#Analize elements
#cx_x = [c_x.iloc[:,0], x.iloc[:,0]]
KKT_LU = np.array([KKT_mat0-LU0])

# %%
n = 1720
KKT_mat0 = KKT_mat.iloc[:,n]
LU0 = LU.iloc[:,n]
KKT_LU = np.array([KKT_mat0-LU0])
np.sum(KKT_LU)
# Out:
# -6.626915451e-16

# %%
KKT_LU = np.array([KKT_mat0-LU0])
KKT_LU.shape
# Out:
# (1, 1727)

# %%
np.sum(KKT_LU)
# Out:
# -6.612287599999994e-23

# %%
#Read csv
c_x = pd.read_csv('ValidarDatos/c_x15.csv')
x = pd.read_csv('ValidarDatosM/x15.csv')
#Iloc
c_x0 = c_x.iloc[:,0]
x0 = x.iloc[:,0]
#Analize elements
#cx_x = [c_x.iloc[:,0], x.iloc[:,0]]
cx_x0 = np.array([c_x0-x0])

# %%
np.sum(cx_x0)
# Out:
# -34.42424699999997

# %%
#Read csv
c_x_prev = pd.read_csv('ValidarDatos/c_x_prev15.csv')
x_prev = pd.read_csv('ValidarDatosM/x_prev15.csv')
#Iloc
c_x0_prev = c_x_prev.iloc[:,0]
x0_prev = x_prev.iloc[:,0]
#Analize elements
#cx_x = [c_x.iloc[:,0], x.iloc[:,0]]
cx_x0_prev = np.array([c_x0_prev-x0_prev])

# %%
np.sum(cx_x0_prev)
# Out:
# -50.347260000000034

# %%
#Read csv
c_y = pd.read_csv('ValidarDatos/c_y15.csv')
y = pd.read_csv('ValidarDatosM/y15.csv')
#Iloc
c_y0 = c_y.iloc[:,0]
y0 = y.iloc[:,0]
#Analize elements
#cx_x = [c_x.iloc[:,0], .iloc[:,0]]
cy_y0 = np.array([c_y0-y0])

# %%
np.sum(cy_y0)
# Out:
# -19.751589999998025

# %%
#Read csv
c_y_fgrad = pd.read_csv('ValidarDatos/c_y_fgrad18.csv')
y_fgrad = pd.read_csv('ValidarDatosM/y_fgrad18.csv')
#Iloc
c_y0_fgrad = c_y_fgrad.iloc[:,0]
y0_fgrad = y_fgrad.iloc[:,0]
#Analize elements
#cx_x = [c_x.iloc[:,0], .iloc[:,0]]
cy_y0_fgrad = np.array([c_y0_fgrad-y0_fgrad])

# %%
np.sum(cy_y0_fgrad)
# Out:
# -0.08117127675473057

# %%
#Read csv
c_KKT_rhs = pd.read_csv('ValidarDatos/c_KKT_rhs15.csv')
KKT_rhs = pd.read_csv('ValidarDatosM/KKT_rhs15.csv')
#Iloc
c_KKT_rhs0 = c_KKT_rhs.iloc[:,0]
KKT_rhs0 = KKT_rhs.iloc[:,0]
#Analize elements
#cx_x = [c_x.iloc[:,0], .iloc[:,0]]
c_KKT_rhs00 = np.array([c_KKT_rhs0-KKT_rhs0])

# %%
np.sum(c_KKT_rhs00)
# Out:
# 0.07356663418159526

# %%
#Read csv
c_p = pd.read_csv('ValidarDatos/c_p16.csv')
p = pd.read_csv('ValidarDatosM/p15.csv')
#Iloc
c_p0 = c_p.iloc[:,0]
p0 = p.iloc[:,0]
#Analize elements
#cx_x = [c_x.iloc[:,0], .iloc[:,0]]
cp_p0 = np.array([c_p0-p0])

# %%
np.sum(cp_p0)
# Out:
# 979.8777513567886

# %%
#Read csv
c_p_lambda = pd.read_csv('ValidarDatos/c_p_lambda15.csv')
p_lambda = pd.read_csv('ValidarDatosM/p_lambda15.csv')
#Iloc
c_p0_lambda = c_p_lambda.iloc[:,0]
p0_lambda = p_lambda.iloc[:,0]
#Analize elements
#cx_x = [c_x.iloc[:,0], .iloc[:,0]]
cp_p0_lambda = np.array([c_p0_lambda-p0_lambda])

# %%
np.sum(cp_p0_lambda)
# Out:
# 978.8615448030623

# %%
p_lambda.shape
# Out:
# (1727, 1)

# %%
cx_x0[:,0:803]
# Out:
# array([[ 1.00e-03, -3.00e-03,  5.00e-03,  1.00e-03,  1.00e-03, -5.00e-03,
#         -5.00e-03,  0.00e+00,  1.00e-03, -1.00e-03, -2.00e-03, -4.00e-03,
#         -3.00e-03,  0.00e+00, -5.00e-03, -2.00e-03, -1.00e-03,  2.00e-03,
#         -2.00e-03, -4.00e-03, -3.00e-03, -3.00e-03,  1.00e-03,  5.00e-03,
#          5.00e-03,  4.00e-03, -2.00e-03,  2.00e-03, -1.00e-03, -5.00e-03,
#          1.00e-03,  4.00e-03, -2.00e-03,  0.00e+00,  2.00e-03,  4.00e-03,
#          0.00e+00,  3.00e-03,  2.00e-03, -4.00e-03, -2.00e-03,  3.00e-03,
#         -2.00e-03,  3.00e-03,  1.00e-03,  2.00e-03, -3.00e-04, -2.00e-04,
#          4.00e-03,  0.00e+00,  1.00e-04,  2.00e-04,  2.00e-04, -2.00e-03,
#          1.00e-03, -2.00e-04,  5.00e-04, -1.00e-03,  4.00e-03, -4.00e-03,
#          0.00e+00, -4.00e-03,  2.00e-03, -2.00e-03, -5.00e-03,  0.00e+00,
#          0.00e+00,  0.00e+00, -5.00e-03,  3.00e-03,  0.00e+00,  1.00e-04,
#         -4.00e-03,  0.00e+00, -4.00e-03, -1.00e-03, -4.00e-03, -4.00e-03,
# ...

# %%
cx_x0[:,803:1607]
# Out:
# array([[ 5.0e-03,  5.0e-03,  4.0e-03,  4.0e-03, -1.0e-03,  5.0e-03,
#          2.0e-03,  5.0e-03,  0.0e+00,  3.0e-03,  5.0e-03,  3.0e-03,
#          0.0e+00,  3.0e-03, -3.0e-03, -1.0e-03, -2.0e-03,  4.0e-03,
#          1.0e-03,  5.0e-03,  2.0e-03, -5.0e-03,  4.0e-03, -1.0e-03,
#          1.0e-03, -4.0e-03, -2.0e-03,  3.0e-03,  4.0e-03, -3.0e-03,
#         -3.0e-03,  0.0e+00,  1.0e-03, -2.0e-03, -1.0e-03,  4.0e-03,
#          3.0e-03,  4.0e-03, -1.0e-03, -5.0e-03, -3.0e-03,  0.0e+00,
#         -1.0e-03, -1.0e-03, -1.0e-03,  1.0e-03,  4.0e-03,  3.0e-03,
#         -1.0e-03, -1.0e-03, -3.0e-03,  4.0e-03, -3.0e-03, -1.0e-03,
#          2.0e-03,  0.0e+00,  3.0e-03, -5.0e-03,  0.0e+00, -5.0e-03,
#         -2.0e-03, -5.0e-03,  1.0e-03,  5.0e-03,  0.0e+00,  3.0e-03,
#          5.0e-03, -4.0e-03,  3.0e-03,  0.0e+00, -4.0e-03,  0.0e+00,
#          4.0e-03, -2.0e-03,  5.0e-03,  5.0e-03,  5.0e-03, -1.0e-03,
#          0.0e+00, -1.0e-03, -2.0e-03,  3.0e-03, -2.0e-03, -4.0e-03,
# ...
